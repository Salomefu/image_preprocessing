# %%
from skimage import io,data

# %%
img = data.moon()
io.imshow(img)
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
from skimage import data_dir
print(data_dir)
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/data

# %%
# !ls /anaconda3/lib/python3.6/site-packages/skimage/data
# Out:
# __init__.py                   foo3x5x4indexed.png
# __pycache__                   grass.png
# _binary_blobs.py              gray_morph_output.npz
# _blobs_3d_fiji_skeleton.tif   horse.png
# astronaut.png                 hubble_deep_field.jpg
# astronaut_GRAY_hog_L1.npy     ihc.png
# astronaut_GRAY_hog_L2-Hys.npy logo.png
# block.png                     moon.png
# brick.png                     motorcycle_disp.npz
# bw_text.png                   motorcycle_left.png
# bw_text_skeleton.npy          motorcycle_right.png
# camera.png                    mssim_matlab_output.npz
# checker_bilevel.png           multi.fits
# chelsea.png                   multipage.tif
# chessboard_GRAY.png           multipage_rgb.tif
# chessboard_GRAY_U16.tif       no_time_for_that_tiny.gif
# chessboard_GRAY_U16B.tif      orb_descriptor_positions.txt
# chessboard_GRAY_U8.npy        page.png
# chessboard_GRAY_U8.npz        palette_color.png
# chessboard_RGB.png            palette_gray.png
# ...
